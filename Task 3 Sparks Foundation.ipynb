# %% [markdown]
# ## Author: Anmol Khera

# %% [markdown]
# # Task 3: Exploratory Data Analysis

# %%
#Importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#Importing sample superstore data using pandas
df = pd.read_csv('SampleSuperstore.csv')
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %%
df.shape
# Out:
# (9994, 13)

# %%
#getting statistical information of data
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
#No. of uniques of every column in the the dataset
df.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
#Checking any null value in the dataset
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# ### Bivariate Analysis

# %%
plt.figure(figsize=(10,8))
sns.distplot(df['Sales'], color= 'blue')
plt.title('Distribution by Sales')
# Out:
# Text(0.5, 1.0, 'Distribution by Sales')

# %% [markdown]
# #### Analysis: From the above plot, we can see that sales is positively skewed.

# %%
plt.figure(figsize=(10,8))
sns.distplot(df['Profit'], color= 'red')
plt.title('Distribution by Profit')
# Out:
# Text(0.5, 1.0, 'Distribution by Profit')

# %% [markdown]
# #### Analysis: From the above plot, we can say that profit is normally distributed

# %%
plt.figure(figsize=(10,8))
sns.distplot(df['Discount'], color= 'orange')
plt.title('Distribution by Discount')
# Out:
# Text(0.5, 1.0, 'Distribution by Discount')

# %%
plt.figure(figsize=(10,8))
sns.distplot(df['Quantity'], color= 'green')
plt.title('Distribution by Discount')
# Out:
# Text(0.5, 1.0, 'Distribution by Discount')

# %%
plt.figure(figsize=(7,7))
sns.heatmap(df.corr(), annot=True, cmap='Blues')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Analysis: From the above heatmap, we can see that:
#             1. Profit and sales are moderately correlated.
#             2. Discount and Profit are negatively correlated.

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)
sns.countplot(df['Category'])
plt.title('Category', fontsize=25)

plt.subplot(1,2,2)
sns.countplot(df['Region'])
plt.title('Region', fontsize=25)

plt.show()

# %% [markdown]
# #### Analysis: From the above plots, we can see that:
#     Office Supplies category have higher no. of dealings.
#
#     West region has the most highest no. of dealings.

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)
sns.countplot(df['Segment'])
plt.title('Segment', fontsize=25)

plt.subplot(1,2,2)
sns.countplot(df['Ship Mode'])
plt.title('Ship Mode', fontsize=25)

plt.show()

# %% [markdown]
# #### Analysis: From the above plot, we can say that:
#     Consumer Segment have higher no. of dealings.
#
#     Standard class shipping mode is highly used for dealings.

# %%
plt.figure(figsize=(20,8))
sns.countplot(df['Sub-Category'])
plt.title('Sub-Category', fontsize=25)
# Out:
# Text(0.5, 1.0, 'Sub-Category')

# %% [markdown]
# #### Analysis: From the above bar plot, we can say that top 3 sub categories that have most no. of sales are Binders, Paper, Furnishings.

# %%
plt.figure(figsize=(20,8))
sns.countplot(df['Quantity'])
plt.title('Quantity', fontsize=25)
plt.show()

# %%
statewise_count= df['State'].value_counts()
statewise_count.head()
# Out:
# California      2001
# New York        1128
# Texas            985
# Pennsylvania     587
# Washington       506
# Name: State, dtype: int64

# %%
statewise_count.plot(kind='bar', figsize=(20,8))
plt.title('State', fontsize=25)
plt.xlabel('States')
plt.ylabel('No. of Counts')
plt.show()

# %% [markdown]
# #### Analysis: From the above plot, we can say that California, New York and Texas are the states that have highest dealings.

# %%
citywise_count= df['City'].value_counts().nlargest(40)
citywise_count.head()
# Out:
# New York City    915
# Los Angeles      747
# Philadelphia     537
# San Francisco    510
# Seattle          428
# Name: City, dtype: int64

# %%
citywise_count.plot(kind='bar', figsize=(20,8))
plt.title('City', fontsize=25)
plt.xlabel('City')
plt.ylabel('No. of Counts')
plt.show()

# %% [markdown]
# #### Analysis: From the above bar plot, we can say that New York City, Los Angeles and Philadelphia are the top 3 cities that have the highest dealings.

# %% [markdown]
# ### Segment distribution of discount, sales and profit

# %%
segmentwise_distribution = df.groupby(['Segment'])[['Discount', 'Sales', 'Profit']].mean()
segmentwise_distribution
# Out:
#              Discount       Sales     Profit
# Segment
# Consumer     0.158141  223.733644  25.836873
# Corporate    0.158228  233.823300  30.456667
# Home Office  0.147128  240.972041  33.818664

# %%
colors= ('orange', 'cyan', 'magenta')

# %%
segmentwise_distribution.plot.pie(subplots=True,
                                  figsize=(20,20),
                                  autopct='%1.1f%%',
                                  labels=segmentwise_distribution.index,
                                  startangle=90,
                                  colors=colors,
                                  shadow=True)
plt.title('Segment-wise distribution of Sales, Discount and Profit', fontsize=20)
plt.show()

# %% [markdown]
# #### Analysis: From the above pie plots-
#     Discount distribution in respective segments are listed below:
#     Consumer 34%
#     Home Office 31.7%
#     Corporate 34%
#
#     Sales distribution in respective segments are listed below:
#     Consumer 32%
#     Home Office 34.5%
#     Corporate 33.5%
#
#     Profit distribution in respective segments are listed below:
#     Consumer 28.7%
#     Home Office 37.5%
#     Corporate 33.8%
#
# Discount and Sales are higher in consumer segment but low in profit.

# %%
statewise_distribution= df.groupby(['State'])[['Discount', 'Sales', 'Profit']].mean()
statewise_distribution.head()
# Out:
#             Discount       Sales     Profit
# State
# Alabama     0.000000  319.846557  94.865989
# Arizona     0.303571  157.508933 -15.303235
# Arkansas    0.000000  194.635500  66.811452
# California  0.072764  228.729451  38.171608
# Colorado    0.316484  176.418231 -35.867351

# %%
state_profit_sort= statewise_distribution.sort_values('Profit')
state_profit_sort['Profit'].plot(kind='bar', figsize=(20,8), color='red')
plt.title('State-wise Distribution of Profit', fontsize=25)
plt.xlabel('State')
plt.ylabel('Profit')
plt.show()

# %% [markdown]
# #### Analysis: From the above plot, we can say that Vermont and Rhode Island are the top states that have highest Profit.

# %% [markdown]
# ### State-wise Distribution of Sales

# %%
statewise_sales= statewise_distribution.sort_values('Sales')
statewise_sales.head()
# Out:
#               Discount       Sales     Profit
# State
# South Dakota  0.000000  109.630000  32.902358
# Kansas        0.000000  121.429583  34.851813
# New Mexico    0.059459  129.284378  31.273408
# North Dakota  0.000000  131.415714  32.878529
# Oregon        0.288710  140.573790  -9.600569

# %%
statewise_sales['Sales'].plot(kind='bar', figsize=(20,8), color='green')
plt.title('Sales in the States', fontsize=25)
plt.xlabel('State')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# #### Analysis: From the above plot, we can say that Wyoming and Vermont are the top States that are highest in Sales.

# %%
citywise_distribution= df.groupby(['City'])[['Discount', 'Sales', 'Profit']].mean()
citywise_distribution.head()
# Out:
#              Discount       Sales     Profit
# City
# Aberdeen     0.000000   25.500000   6.630000
# Abilene      0.800000    1.392000  -3.758400
# Akron        0.357143  129.999333  -8.887410
# Albuquerque  0.057143  158.582857  45.292007
# Alexandria   0.000000  344.973125  19.913644

# %% [markdown]
# ### City-wise distribution of Sales

# %%
citywise_sales= citywise_distribution.sort_values('Sales')
citywise_sales.head()
# Out:
#               Discount  Sales  Profit
# City
# Abilene            0.8  1.392 -3.7584
# Elyria             0.7  1.824 -1.3984
# Jupiter            0.2  2.064  0.1548
# Pensacola          0.7  2.214 -1.4760
# Ormond Beach       0.7  2.808 -1.9656

# %%
citywise_sales['Sales'].head(30).plot(kind='bar', figsize=(20,8), color= 'orange')
plt.title('Sales in the Cities', fontsize=25)
plt.show()

# %% [markdown]
# #### Analysis: From the above plot, we can say that Portage, Grand Island and Margate are the top Cities with highest Sales.

# %%
citywise_profit= citywise_distribution.sort_values('Profit')
citywise_profit.head()
# Out:
#             Discount       Sales      Profit
# City
# Bethlehem   0.380000  337.926800 -200.619160
# Champaign   0.600000  151.960000 -182.352000
# Oswego      0.600000  107.326000 -178.709200
# Round Rock  0.274286  693.436114 -169.061614
# Lancaster   0.315217  215.031826 -157.371052

# %%
citywise_profit['Profit'].head(30).plot(kind='bar', figsize=(20,8), color='#8B2323')
plt.title('City-wise distribution of Profit', fontsize=25)
plt.xlabel('City')
plt.ylabel('Profit')
# Out:
# Text(0, 0.5, 'Profit')

# %%
citywise_profit['Profit'].tail(30).plot(kind='bar', figsize=(20,8), color='#8B2323')
plt.title('City-wise distribution of Profit', fontsize=25)
plt.xlabel('City')
plt.ylabel('Profit')
# Out:
# Text(0, 0.5, 'Profit')

# %% [markdown]
# #### Analysis: From the above plots, we can say that Bethlehem, Champaign and Oswego are the top 3 Cities having lowest Profit, whereas Jamestown, Independence and Lafayette are cities containing highest profit.

# %%
statewise_discount= statewise_distribution.sort_values('Discount')
statewise_discount.head()
# Out:
#              Discount       Sales     Profit
# State
# Alabama           0.0  319.846557  94.865989
# Nebraska          0.0  196.445526  53.607742
# Wisconsin         0.0  291.951000  76.380004
# Missouri          0.0  336.441667  97.518341
# Mississippi       0.0  203.232830  59.867475

# %%
statewise_discount['Discount'].plot(kind='bar', figsize=(20,8), color='#76EE00')
plt.title('State-wise distribution of Discount', fontsize=25)
plt.xlabel('State')
plt.ylabel('Discount')
plt.show()

# %% [markdown]
# #### Analysis: From the above plot, we can say that Illinois, Texas and Pennsylvania are the top 3 States that gave highest discounts on their Sales.

# %%
citywise_discount= citywise_distribution.sort_values('Discount')
citywise_discount.head()
# Out:
#              Discount       Sales     Profit
# City
# Aberdeen          0.0   25.500000   6.630000
# Eagan             0.0   26.785000  10.879225
# East Orange       0.0   75.454000  34.923820
# East Point        0.0   89.466667  34.004600
# Eau Claire        0.0  274.275000  71.249633

# %%
citywise_discount['Discount'].tail(30).plot(kind='bar', figsize=(20,8), color='#6495ED')
plt.title('City-wise distribution of Discount', fontsize=25)
plt.xlabel('City')
plt.ylabel('Discount')
plt.show()

# %% [markdown]
# #### Analysis: From the above plot, we can say that Missouri City, Abilene, Deer park and Romeoville are the top 4 Cities that gave highest discounts on their Sales.

# %%
statewise_qua= df.groupby(['State'])[['Quantity', 'Sales', 'Profit']].mean()
statewise_qua.head()
# Out:
#             Quantity       Sales     Profit
# State
# Alabama     4.196721  319.846557  94.865989
# Arizona     3.848214  157.508933 -15.303235
# Arkansas    4.000000  194.635500  66.811452
# California  3.831584  228.729451  38.171608
# Colorado    3.807692  176.418231 -35.867351

# %%
statewise_qua_sort= statewise_qua.sort_values('Quantity')
statewise_qua_sort.head()
# Out:
#               Quantity       Sales     Profit
# State
# Idaho         3.047619  208.689810  39.367767
# Kansas        3.083333  121.429583  34.851813
# Connecticut   3.426829  163.223866  42.823071
# New Jersey    3.492308  275.110092  75.176260
# South Dakota  3.500000  109.630000  32.902358

# %%
statewise_qua_sort['Quantity'].plot(kind='bar', figsize=(20,8), color='#BF3EFF')
plt.title('Statewise distribution of Quantity', fontsize=25)
plt.xlabel('State')
plt.ylabel('Quantity')
plt.show()

# %% [markdown]
# #### Analysis: From the above plot, we can say that New Hampshire, Vermont and West verginia are the top 3 States that sells most of the quantities.

# %%
category_dist= df.groupby(['Category'])[['Sales', 'Discount', 'Profit']].mean()
category_dist.head()
# Out:
#                       Sales  Discount     Profit
# Category
# Furniture        349.834887  0.173923   8.699327
# Office Supplies  119.324101  0.157285  20.327050
# Technology       452.709276  0.132323  78.752002

# %%
category_dist.plot.pie(autopct='%1.1f%%',
                      subplots=True,
                      figsize=(20,20),
                      shadow=True,
                      colors=colors,
                      startangle=90,
                      labels=category_dist.index)
plt.title('Category-wise distribution of Sales, Discount and Profit', fontsize=25)
plt.show()

# %% [markdown]
# #### From the above pie plots, we can say that:
#     Sales
#     Furniture 38%
#     Technology 49%
#     Office Supplies 12.9%
#
#     Discount
#     Furniture 37.5%
#     Technology 28.5%
#     Office Supplies 33.9%
#
#     Profit
#     Furniture 8%
#     Technology 73%
#     Office Supplies 19%

# %%
subcategory_dist= df.groupby(['Sub-Category'])[['Sales', 'Discount', 'Profit']].mean()
subcategory_dist
# Out:
#                     Sales  Discount      Profit
# Sub-Category
# Accessories    215.974604  0.078452   54.111788
# Appliances     230.755710  0.166524   38.922758
# Art             34.068834  0.074874    8.200737
# Binders        133.560560  0.372292   19.843574
# Bookcases      503.859633  0.211140  -15.230509
# Chairs         532.332420  0.170178   43.095894
# Copiers       2198.941618  0.161765  817.909190
# Envelopes       64.867724  0.080315   27.418019
# Fasteners       13.936774  0.082028    4.375660
# Furnishings     95.825668  0.138349   13.645918
# Labels          34.303055  0.068681   15.236962
# Machines      1645.553313  0.306087   29.432669
# Paper           57.284092  0.074891   24.856620
# Phones         371.211534  0.154556   50.073938
# Storage        264.590553  0.074704   25.152277
# Supplies       245.650200  0.076842   -6.258418
# Tables         648.794771  0.261285  -55.565771

# %%
subcategory_dist.plot(kind='bar', figsize=(20,8), legend=['Sales', 'Discount', 'Profit'])
plt.title('SubCategory-wise distribution of Sales, Discount and Profit', fontsize=25)
plt.show()

# %% [markdown]
# #### Analysis: From the above plot, we can say that Copiers, Machines and Tables are the top 3 sub-categories have highest amount of sales, whereas Copiers and Accessories having highest amount of profit.

# %% [markdown]
# ### Region Distribution

# %%
region_dist= df.groupby(['Region'])[['Discount', 'Sales', 'Profit']].mean()
region_dist
# Out:
#          Discount       Sales     Profit
# Region
# Central  0.240353  215.772661  17.092709
# East     0.145365  238.336110  32.135808
# South    0.147253  241.803645  28.857673
# West     0.109335  226.493233  33.849032

# %%
colors2= ('#BF3EFF', '#FF1493', '#ADFF2F', '#ADD8E6')

# %%
region_dist.plot.pie(autopct='%1.1f%%',
                    subplots=True,
                    figsize=(20,35),
                    shadow=True,
                    startangle=90,
                    labels=region_dist.index,
                    colors=colors2)
plt.title('Region-wise distribution of Sales, Discount and Profit', fontsize=25)
plt.show()

# %% [markdown]
# #### From the above plot, we can say that:
#     Discount
#     East 22.6%
#     West 17%
#     Central 37.4%
#     South 23%
#
#     Sales
#     East 26%
#     West 24.6%
#     Central 23.4%
#     South 26%
#
#     Profit
#     East 28.7%
#     West 30%
#     Central 15.3%
#     South 26%

# %%
shipmode_dist= df.groupby(['Ship Mode'])[['Discount', 'Sales', 'Profit']].mean()
shipmode_dist
# Out:
#                 Discount       Sales     Profit
# Ship Mode
# First Class     0.164610  228.497024  31.839948
# Same Day        0.152394  236.396179  29.266591
# Second Class    0.138895  236.089239  29.535545
# Standard Class  0.160023  227.583067  27.494770

# %%
shipmode_dist.plot.pie(autopct='%1.1f%%',
                    subplots=True,
                    figsize=(20,30),
                    shadow=True,
                    startangle=90,
                    labels=shipmode_dist.index,
                    colors=colors2)
plt.title('Ship Mode-wise distribution of Sales, Discount and Profit', fontsize=25)
plt.show()

# %% [markdown]
# #### Analysis: From the above pie plots, we can say that:
#     Discount
#     First Class 26.7%
#     Second Class 22.6%
#     Standard Class 26%
#     Same Day 24.7%
#
#     Sales
#     First Class 24.6%
#     Second Class 25.4%
#     Standard Class 24.5%
#     Same Day 25.5%
#
#     Profit
#     First Class 27%
#     Second Class 25%
#     Standard Class 23.3%
#     Same Day 25%

# %% [markdown]
# ### Problem Statement:

# %% [markdown]
# #### As a business manager, try to find out the weak areas where you can work to make more profit.
# ● What all business problems you can derive by exploring the data?

# %% [markdown]
# ### Final Analysis:

# %% [markdown]
# * Top States that have highest profit: Vermont and Rhode, lowest profit: Ohio and Colorado.
#
# Remark: We can increase the sales in Vermont and Rhode as these states are higher in profit and decrease the sales in Ohio and  Colorado.
#
# * Top Cities that have highest profit: Jamestown, Independence and Lafayette, lowest profit: Bethlehem, Champaign and Oswego.
#
# Remark: We can increase our sales in highest profit cities and decrease in lowest profit cities.
#
# * We can decrease our sales in Consumer segment as compared to other segments as it is less profitable and incease our sales in Office Supplies and Corporate Segment. We can also increase discount on sales in these segments as well.
#
# * Top States having highest sales: Wyoming and Vermont.
#
# Remark: We can decrease the sales in Wyoming.
#
# * Top Cities having highest sales: Portage, Grand Island and Margate.
#
# Remark: We can decrease the sales in these cities.
#
# * We need to decrease our sales in Furniture and Office Supplies as it has lowest profit.
#
# * We can increase our sales in Technology Category as it makes highest profit.
#
# * Top sub-categories having highest sales: Copiers, Machines and Tables, highest profit: Copiers and Accessories.
#
# Remark: We can increase our sales in Accessories as it also makes higher profit.
#
# * We need to decrease our sales in Tables sub-Category as it is making loss in sales.
#
# * We can increase our sales in East and West region as they make highest profit and decrease our sales in Central region.
